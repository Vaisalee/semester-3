# %%
import time

# %%
print("\t\t welcome to automobile ai expert system\t\t")
print("\n\n ai:do you have any problems with your vehicle?(s\n)\n")
choice1=input("you:")

if choice1=="s":
    print("\n enter the type of your issues list down below:\n 1.starting trouble \n 2.woubble while driving\n3.i didn't have any issues\n")
    choice2=input("\n enter here(numbers only)")
    
    if choice2 >"3" or choice2 <"1":
        print("\n ai :please enter valid key...")
    
    elif choice2=="3":
        print("\n ai : then,why are you enter yes for the first question")
    
    elif choice2=="2":
        print("\n ai :ok let me think..|\n")
        for i in range(1,20):
            time.sleep(0.08)
            print(".",flush=True,end=" ")
        print("\n ai: when do you feel the woubbling \n1. while drive on the highway at terrible speed \n2. while drive normal road \n")
        
        choice3=input("u:")
        
        if choice3=="1":
            print("\n ai : please wait still....\nAI : i wanna call police...\nAI : just kidding...go slow my friend")
            
        elif choice3=="2":
            print("\n ai: check your tire air pressure then check inform me kindly")
            print("\n ai : still u feel wobble?(yes\no)\n")
            choice4=input("u:")
            
            
            if choice4=="no":
                print("\n ai : i'm glad to help u.....\n thank you...\n call me again...")
            
            elif choice4=="yes":
                print("\n ai : i think, you have to make a phone call to your service center.....\n thank you")
            else:
                print("\n ai : will u please enter the correct answer......")
                
                
        else:
            print("\n ai : please enter the valid key")
            
    else:
        print("\n ai : let me remember that u have to check that the key is inserted ? \n ai : is it inserted ?(yes\no)")
        choice5=input("\n you:")
        
        if choice5=="no":
            print("\n ai: i think you have study hard....better then ride a bike....\n ai : thank you...!")
            
        elif choice5=="yes":
            print("\n ai : oh i see...let me think what to do wait...\n")
            
            
            for i in range (1,30):
                time.sleep(0.08)
                print(".",flush=True,end=" ")
                
            print("\n\n ai : sorry bro i dont know.....\n i think you have to reach the service center....")
            
            
        else:
            print("\n  ai : i'm getting bore when u enter the wrong answer....")
     
elif choice1=="n":
        print("\n ai : then y did u waste your time")
        
else:
        print("ai : enter valid key")
# Out:
# 		 welcome to automobile ai expert system
#
#
#  ai:do you have any problems with your vehicle?(s
# )
#
# you:s
#
#  enter the type of your issues list down below:
#  1.starting trouble
#  2.woubble while driving
# 3.i didn't have any issues
#
#
#  enter here(numbers only)1
#
#  ai : let me remember that u have to check that the key is inserted ?
#  ai : is it inserted ?(yes
# o)
#
#  you:yes
#
#  ai : oh i see...let me think what to do wait...
#
# . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
#
#  ai : sorry bro i dont know.....
#  i think you have to reach the service center....
